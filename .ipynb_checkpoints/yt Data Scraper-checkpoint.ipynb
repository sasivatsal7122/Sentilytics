# %%
import csv
from googleapiclient.discovery import build
from collections import Counter
import streamlit as st
from googleapiclient.errors import HttpError
import re
from pytube import YouTube
import yt_dlp
from tqdm.auto import tqdm
import pandas as pd
from datetime import datetime
import requests
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # API keys config

# %%
DEVELOPER_KEY = "AIzaSyD_NG--GtmImIOhDhp-5V6PFPmJhiiZN88"
YOUTUBE_API_SERVICE_NAME = 'youtube'
YOUTUBE_API_VERSION = 'v3'
youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=DEVELOPER_KEY)
# Out:
# 2023-06-01 23:41:15.852 INFO    googleapiclient.discovery_cache: file_cache is only supported with oauth2client<4.0.0

# %% [markdown]
# # Define Channel Link

# %%
channel_link = "https://www.youtube.com/@beebomco"

# %% [markdown]
# # Get Basic Channel Info

# %%
def get_channel_info(channel_link):
    
    match = re.search(r'/@([^/]+)', channel_link)
    if match:
        username = match.group(1)
        response = requests.get(f"https://youtube.googleapis.com/youtube/v3/search?part=snippet&q={username}&type=channel&key={DEVELOPER_KEY}").json()
        channel_id =  response['items'][0]['id']['channelId']
    else:
        print('Invalid channel link')
        return None

    channel_info = {
        'channel_id': channel_id,
        'channel_title': '',
        'video_count': 0,
        'channel_logo_url': '',
        'channel_created_date': '',
        'subscriber_count': 0,
        'channel_description': ''
    }

    try:
        response = youtube.channels().list(
            part='snippet,statistics',
            id=channel_id
        ).execute()

        if 'items' in response and len(response['items']) > 0:
            channel = response['items'][0]
            channel_info['channel_title'] = channel['snippet']['title']
            channel_info['video_count'] = int(channel['statistics']['videoCount'])
            channel_info['channel_logo_url'] = channel['snippet']['thumbnails']['default']['url']
            channel_info['channel_created_date'] = datetime.strptime(channel['snippet']['publishedAt'], "%Y-%m-%dT%H:%M:%SZ").strftime("%B %d, %Y")
            channel_info['subscriber_count'] = int(channel['statistics']['subscriberCount'])
            channel_info['channel_description'] = channel['snippet']['description']

        return channel_info

    except HttpError as e:
        print(f'An HTTP error occurred: {e}')
        return None

# %% [markdown]
# # Get Latest 20 Videos of the channel with complete info

# %%
def get_latest20(channel_id):
    channel_url = f'https://www.youtube.com/channel/{channel_id}/videos'

    ydl_opts = {
        'format': 'best',
        'quiet': True,
        'no_warnings': True,
        'ignoreerrors': True,
        'skip_download': True,
        'getduration': True,
        'getdescription': True,
        'getuploaddate': True,
        'playlistend': 20
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info_dict = ydl.extract_info(channel_url, download=False)
        videos = info_dict['entries']
        
    video_data = []
    for video in videos:
        video_id = video['id']
        title = video['title']
        url = video['webpage_url']
        description = video.get('description', '')
        duration = video.get('duration')
        published_at = video.get('upload_date', '')
        thumbnails = video.get('thumbnails', [])
        view_count = video.get('view_count', 0)
        like_count = video.get('like_count', 0)
        comment_count = video.get('comment_count', 0)
        minutes, seconds = divmod(duration, 60)
        
        video_data.append({
            'video_id': video_id,
            'title': title,
            'url': url,
            'description': description,
            'duration': f'{minutes:02d}:{seconds:02d}',
            'published_at': datetime.strptime(published_at, "%Y%m%d").strftime("%B %d, %Y"),
            'thumbnails': thumbnails[-1]['url'],
            'view_count': view_count,
            'like_count': like_count,
            'comment_count': comment_count
    })
        
    return video_data

# %%
channel_info = get_channel_info(channel_link)
channel_info
# Out:
# {'channel_id': 'UCvpfclapgcuJo0M_x65pfRw',
#  'channel_title': 'Beebom',
#  'video_count': 1013,
#  'channel_logo_url': 'https://yt3.ggpht.com/ytc/AGIKgqNyTSv58cVWlODIvhYc54XpXgIIMe8bUI_cn2Sc7A=s88-c-k-c0x00ffffff-no-rj',
#  'channel_created_date': 'February 09, 2016',
#  'subscriber_count': 2760000,
#  'channel_description': "Beebom's official YouTube Channel.\n\nOfficial Twitter Handle: https://twitter.com/beebomco/\n"}

# %%
video_data = get_latest50(channel_id)
df = pd.DataFrame(video_data)
df['channel_id'] = channel_info['channel_id']

# %%
df
# Out:
#        video_id                                              title  \
# 0   dPLj_lId_zY   Lava Agni 2 Review: The Good, The Bad, The Best!
# 1   QOm4okp1J5c             Moto Edge 40: A Good Option Under 30K?
# 2   0YoPpEIS3o4               8 Super Useful Gadgets for Students!
# 3   MDigRlLPlgc  ASUS ROG Strix G18: Core i9 + 4070 at Great Pr...
# 4   Q65Fn1FZwdE   Dell G16 (2023): High Performance, Better Price!
# 5   lUDozITit6w                         Pixel 7a: Google Fixed It!
# 6   0d5vOvvP8qk                  POCO F5: Snapdragon 7+ Gen 2 is 🔥
# 7   JdgWV-e-RR8  ASUS Zenbook Pro 14 Duo (2023): Dual Screens G...
# 8   3MZ6aTpFrE0   15 Quality Deals on Flipkart & Amazon Right Now!
# 9   Gb_i_W7Ko3Y                      The Best Phone Under ₹20,000!
# 10  YOIw5r0qEGo  Tecno Phantom V Fold: Finally, An Affordable F...
# 11  aURzYhwsyHg            OnePlus Pad: Impressive Android Tablet!
# 12  KBTe0kJM1QY                        7 Awesome Gadgets for Home!
# 13  r4yegw_rgrc  ASUS ZenBook S13 OLED: The Ultra Light Windows...
# 14  3i0HG5kdAno                 The Best Laptop Deal for Students!
# 15  BrtEhtO7mMk                     The Best Phone Deal Right Now!
# 16  eOT8GyDx9EY  Dell Inspiron 16 2-in-1 (2023): Really Good Ha...
# 17  xTIaOLw-2vQ             ROG Phone 7 Ultimate: New Gaming Tech!
# 18  eiVtRoCXwTg    Alienware m18 2023: This is Extremely Powerful!
# 19  _lrKwlUKoOE                   This EV Deserves Your Attention!
#
#                                             url  \
# 0   https://www.youtube.com/watch?v=dPLj_lId_zY
# 1   https://www.youtube.com/watch?v=QOm4okp1J5c
# 2   https://www.youtube.com/watch?v=0YoPpEIS3o4
# 3   https://www.youtube.com/watch?v=MDigRlLPlgc
# 4   https://www.youtube.com/watch?v=Q65Fn1FZwdE
# 5   https://www.youtube.com/watch?v=lUDozITit6w
# 6   https://www.youtube.com/watch?v=0d5vOvvP8qk
# 7   https://www.youtube.com/watch?v=JdgWV-e-RR8
# 8   https://www.youtube.com/watch?v=3MZ6aTpFrE0
# 9   https://www.youtube.com/watch?v=Gb_i_W7Ko3Y
# 10  https://www.youtube.com/watch?v=YOIw5r0qEGo
# 11  https://www.youtube.com/watch?v=aURzYhwsyHg
# 12  https://www.youtube.com/watch?v=KBTe0kJM1QY
# 13  https://www.youtube.com/watch?v=r4yegw_rgrc
# 14  https://www.youtube.com/watch?v=3i0HG5kdAno
# 15  https://www.youtube.com/watch?v=BrtEhtO7mMk
# 16  https://www.youtube.com/watch?v=eOT8GyDx9EY
# 17  https://www.youtube.com/watch?v=xTIaOLw-2vQ
# 18  https://www.youtube.com/watch?v=eiVtRoCXwTg
# 19  https://www.youtube.com/watch?v=_lrKwlUKoOE
#
#                                           description duration  \
# 0   The Lava Agni 2 is here and this is one hyped ...    07:31
# 1   Motorola has launched the new Edge 40 and this...    05:58
# 2   The best gadgets for students! These are 8 sup...    05:09
# 3   ASUS has launched of number of new ROG laptops...    05:33
# 4   The new Dell G16 7630 has arrived and it bring...    05:03
# 5   Google has just launched the Pixel 7a and this...    06:31
# 6   The new POCO F5 is here and it's the first pho...    06:12
# 7   This is the new ASUS Zenbook Pro 14 Duo OLED 2...    05:53
# 8   In this video, we show you 15 quality deals on...    04:56
# 9   This is not your usual best phones video, wher...    04:48
# 10  Tecno recently launched its first foldable pho...    06:07
# 11  OnePlus' first tablet is here, the OnePlus Pad...    06:55
# 12  Check out the free Ice Cream Photo Editor here...    05:24
# 13  The brand new ASUS Zenbook S13 OLED is here an...    05:14
# 14  How about a laptop deal under 35,000 rupees th...    04:47
# 15  A flagship phone from last year with Snapdrago...    05:10
# 16  The all new Dell Inspiron 16 7630 is here and ...    05:29
# 17  The new ROG Phone 7 is here and while it hasn'...    06:18
# 18  The new Alienware m18 is here and it brings po...    05:55
# 19  We all think EVs are impractical, they all loo...    09:01
#
#       published_at                                         thumbnails  \
# 0     May 26, 2023  https://i.ytimg.com/vi_webp/dPLj_lId_zY/maxres...
# 1     May 23, 2023  https://i.ytimg.com/vi_webp/QOm4okp1J5c/maxres...
# 2     May 20, 2023  https://i.ytimg.com/vi_webp/0YoPpEIS3o4/maxres...
# 3     May 17, 2023  https://i.ytimg.com/vi_webp/MDigRlLPlgc/maxres...
# 4     May 15, 2023  https://i.ytimg.com/vi_webp/Q65Fn1FZwdE/maxres...
# 5     May 10, 2023  https://i.ytimg.com/vi_webp/lUDozITit6w/maxres...
# 6     May 09, 2023  https://i.ytimg.com/vi_webp/0d5vOvvP8qk/maxres...
# 7     May 08, 2023  https://i.ytimg.com/vi_webp/JdgWV-e-RR8/maxres...
# 8     May 04, 2023  https://i.ytimg.com/vi_webp/3MZ6aTpFrE0/maxres...
# 9     May 03, 2023  https://i.ytimg.com/vi_webp/Gb_i_W7Ko3Y/maxres...
# 10  April 29, 2023  https://i.ytimg.com/vi_webp/YOIw5r0qEGo/maxres...
# 11  April 28, 2023  https://i.ytimg.com/vi_webp/aURzYhwsyHg/maxres...
# 12  April 26, 2023  https://i.ytimg.com/vi_webp/KBTe0kJM1QY/maxres...
# 13  April 21, 2023  https://i.ytimg.com/vi_webp/r4yegw_rgrc/maxres...
# 14  April 19, 2023  https://i.ytimg.com/vi_webp/3i0HG5kdAno/maxres...
# 15  April 16, 2023  https://i.ytimg.com/vi_webp/BrtEhtO7mMk/maxres...
# 16  April 14, 2023  https://i.ytimg.com/vi_webp/eOT8GyDx9EY/maxres...
# 17  April 13, 2023  https://i.ytimg.com/vi_webp/xTIaOLw-2vQ/maxres...
# 18  April 11, 2023  https://i.ytimg.com/vi_webp/eiVtRoCXwTg/maxres...
# 19  April 05, 2023  https://i.ytimg.com/vi_webp/_lrKwlUKoOE/maxres...
#
#     view_count  like_count  comment_count
# 0       138625        7778            729
# 1       251237        9120           1400
# 2       332175       11752            719
# 3        67458        2555            191
# 4        96253        3518            280
# 5       315269       11189           1600
# 6       297995       10749           1400
# 7        78286        2954            112
# 8       405811       12145            957
# 9      1115577       31774           1700
# 10       98651        3235            206
# 11      404431        9652            824
# 12      627029       22141            344
# 13      117756        4366            251
# 14      273900        8443            503
# 15      538318       16758           1100
# 16       83331        2613            185
# 17       72331        3351            235
# 18       64868        2764            167
# 19      145686        5444            472

# %% [markdown]
# # Downloading High Level Comments

# %%
def get_HighLvlcomments(video_id):

    try:
        comments = []
        response = youtube.commentThreads().list(
            part='snippet',
            videoId=video_id,
            maxResults=100, 
            textFormat='plainText'
        ).execute()

        while response:
            for item in response['items']:
                comment = item['snippet']['topLevelComment']['snippet']
                author = comment['authorDisplayName']
                text = comment['textDisplay']
                comments.append(
                    text
                )

            if 'nextPageToken' in response:
                next_page_token = response['nextPageToken']
                response = youtube.commentThreads().list(
                    part='snippet',
                    videoId=video_id,
                    maxResults=100,  
                    textFormat='plainText',
                    pageToken=next_page_token
                ).execute()
            else:
                break
                
    except HttpError as e:
        print(f'An HTTP error occurred: {e}')
        return None

    return comments

# %%
HighLvlcomments = get_HighLvlcomments("3MZ6aTpFrE0")

# %%
HighLvldf = pd.DataFrame(HighLvlcomments,columns=['Comments'])
HighLvldf['Comment ID'] = np.random.randint(1, 1000000, size=len(HighLvldf))
HighLvldf['Comment ID'] = HighLvldf['Comment ID'].astype(str) + '_' + HighLvldf.groupby('Comment ID').cumcount().add(1).astype(str)
HighLvldf
# Out:
#                                               Comments Comment ID
# 0    Hey Guys! Any other awesome deal that we misse...   197154_1
# 1    Which extension was it you used to track the p...   274067_1
# 2        realme gt neo 3t will be back in sale or not?   857536_1
# 3    Got few deals for myself myself:\n1. Sony WH-1...   724364_1
# 4    Sir, could you please suggest any way to updat...   353754_1
# ..                                                 ...        ...
# 499                                 Good Evening Bee 😁   465840_1
# 500                                        Hum first 😂   743612_1
# 501                                                  😂   857843_1
# 502                                                ❤❤❤   438384_1
# 503                                            First ❤   987781_1
#
# [504 rows x 2 columns]

# %%
HighLvldf.to_csv(f'HighLevel_{videoId}_master.csv')

# %% [markdown]
# # Downloading Both High-level and Low-Level Comments

# %%
def getAllTopLevelCommentReplies(topCommentId, token): 

    replies_response=youtube.comments().list(part='snippet',maxResults=100,parentId=topCommentId,pageToken=token).execute()

    for indx, reply in enumerate(replies_response['items']):
        all_comments.append(reply['snippet']['textDisplay'])

    if "nextPageToken" in replies_response: 
        return getAllTopLevelCommentReplies(topCommentId, replies_response['nextPageToken'])
    else:
        return []

def get_comments(youtube, video_id, token): 
    global all_comments
    totalReplyCount = 0
    token_reply = None

    if (len(token.strip()) == 0): 
        all_comments = []

    if (token == ''): 
        video_response=youtube.commentThreads().list(part='snippet',maxResults=100,videoId=video_id,order='relevance').execute() 
    else: 
        video_response=youtube.commentThreads().list(part='snippet',maxResults=100,videoId=video_id,order='relevance',pageToken=token).execute() 

    for indx, item in enumerate(video_response['items']): 
        all_comments.append(item['snippet']['topLevelComment']['snippet']['textDisplay'])
        totalReplyCount = item['snippet']['totalReplyCount']

        if (totalReplyCount > 0): 
            replies_response=youtube.comments().list(part='snippet',maxResults=100,parentId=item['id']).execute()
            for indx, reply in enumerate(replies_response['items']):
                all_comments.append(reply['snippet']['textDisplay'])

            while "nextPageToken" in replies_response:
                token_reply = replies_response['nextPageToken']
                replies_response=youtube.comments().list(part='snippet',maxResults=100,parentId=item['id'],pageToken=token_reply).execute()
                for indx, reply in enumerate(replies_response['items']):
                    all_comments.append(reply['snippet']['textDisplay'])

    if "nextPageToken" in video_response: 
        return get_comments(youtube, video_id, video_response['nextPageToken']) 
    else: 
        all_comments = [x for x in all_comments if len(x) > 0]
        print("Scraping Comments Completed")
        return []

# %%
videoId = '3MZ6aTpFrE0'

get_comments(youtube,videoId,'')
print("All total comments obtained: "  + str(len(all_comments)))
# Out:
# Scraping Comments Completed
# All total comments obtained: 954

# %%
AllLvldf = pd.DataFrame(all_comments,columns=['Comments'])
AllLvldf['Comment ID'] = np.random.randint(1, 1000000, size=len(AllLvldf))
AllLvldf['Comment ID'] = AllLvldf['Comment ID'].astype(str) + '_' + AllLvldf.groupby('Comment ID').cumcount().add(1).astype(str)
AllLvldf
# Out:
#                                               Comments Comment ID
# 0    Hey Guys! Any other awesome deal that we misse...   298107_1
# 1    What&#39;s best smartphone under 55000-62k INR...   774454_1
# 2    Whats best smartphone for best camera under 50...   378283_1
# 3    Please make best smartphone under 55k... no on...   674053_1
# 4            There is no discount on Asus vivobook pro   390621_1
# ..                                                 ...        ...
# 949  To al those who are saying dont buy s20 fe cuz...   680052_1
# 950  + i see someone commenting Exynos 990. <br><br...   969564_1
# 951             creaky Sound. make this video Annoying   194318_1
# 952                                Amazon is overrated   515685_1
# 953                                  crosses eyes lodu    85359_1
#
# [954 rows x 2 columns]

# %%
AllLvldf.to_csv(f'All_{videoId}_master.csv')

# %%
all_comments
# Out:
# ['Hey Guys! Any other awesome deal that we missed out on? 😇',
#  'What&#39;s best smartphone under 55000-62k INR for best camera???<br><br>Vivo X90 vs Pixel 7 vs OnePlus 11<br>Which is best or anything else?',
#  'Whats best smartphone for best camera under 50-60k?<br><br>Need for office IT professional  work  and personal camera for clicking birds, wildlife and recording videos sometimes..',
#  'Please make best smartphone under 55k... no one touches segment between 45k-55k<br><br>Because for some video recording and clicking pics are important and performance equally...so the only segment left is 45-55k<br>If you can make video on that for best camera smartphone',
#  'There is no discount on Asus vivobook pro',
#  '@Beebom you missed ipad deal. :)',
#  'Realme GT 2 was at 24k.',
#  'Gt Neo 3 t is out of stock 😅😢',
#  'Sony srs xe 200',
#  'Motorola edge 30 ultra',
#  '@Sai Subash Jonnalagadda because of camera and fetures in low price',
#  'What&#39;s best smartphones under 55k for office work and freelance work <br><br>Priority camera and performance',
#  '\u200b@anuj sharma How 33229',
#  'Xiaomi 12 pro vs pixel 6 pro which one should I buy???',
#  'headphone?',
#  'realme gt 2 and gt 2 pro. its actually a good deal.',
#  'Realme Gt2',
#  'Please make the best laptop deals for every user type.',
#  'samsung buds 2 pro now at 10k which is half of its actual price',
#  'What&#39;s other best option that has camera better than Samsung S21FE..even by spending 10k extra<br>With less heating<br>Any recommendations under 40k for best possible camera<br><br>Or<br>Even under 50k for best possible camera<br><br>Less heat.',
#  'Is there any best phone  under 55-56k or maximum 60k with great camera<br><br>Performance: little bit better than average<br>Need less heating as I live in area with high temperature<br><br>What&#39;s best?<br>Pixel 7<br>Vivo x90<br>??',
#  'The pixel 7 is at 45000 in Amazon',
#  '\u200b@Retro Tech pixel 7 is good option other than iPhone 13,14',
#  'What kind of thumbnail is that? Looks like the lad is about to have a seizure',
#  'There are many others but they dont pay for their promotion on your video.',
#  'Philips Wireless On Ear Headphones TAH8506BK,<br>8000 rupees only',
#  'Realme gt 2 under 25k',
#  'Which rice tracking tools are you using?<br>Please share',
#  'I actually got the nothing phone 1 8gb 256gb at 27200 <br>With the SBI card offer that too on no cost emi <br>So does it count ? <a href="http://www.youtube.com/results?search_query=%23beebom">#beebom</a>',
#  'Hi, which website you are using to track the prices of product?',
#  'What&#39;s other best option that has camera better than Samsung S21FE..even by spending 10k extra<br>With less heating<br>Any recommendations under 40k for best possible camera<br><br>Or<br>Even under 50k for best possible camera<br><br>Less heat.',
#  '@Atul Gadekar realme gt neo 3t at 19k',
#  'How about iqoo 9 at 31000 in Amazon ? Is it a good deal?',
#  'Also i just baught Sony XM4 AT 14750',
#  'Pixel 6a?',
#  '@Atul Gadekar get gt neo 3t instead',
#  'I just baught samsung buds 2 pro at 9740 from Amazon which are mostly around 16K',
#  '\u200b@Sai Subash Jonnalagaddaexactly, how is this a good deal OR even a recommendation now?',
#  'Realme gt 2 in 24999',
#  'Samsung S21 fe 5g 256gb version at 33299 rs at Samsung shop.',
#  'Realme GT 2 is available for 24999 its a good deal if you ask me it has SD888',
#  '\u200b@Avinash N I bought them two days back for 9700 on Amazon',
#  'Poco m5 @9749',
#  '\u200b@Atul Gadekar go for realme gt neo3t for 19999 instead',
#  'Sony xm4 and xm5??',
#  'Honor Magicbook X14 i5 12th gen @47k but with coupons and bank discount its available below 44k',
#  'Realme GT2 pro @33k',
#  'There is around 18k off with SBI Credit Card on Samsung Galaxy Book... Please cover it if possible...',
#  'Is sony linkbuds S at an effective price of 10k a good deal?',
#  'Realme GT 2 at 25k',
#  'I think Realme GT2 is a good deal now.',
#  'Watch 5 for around 17k?',
#  'Any monitor to consider in sale😅',
#  'Samsung buds2 Pro. 16k now available at 10.3k with Bank discounts',
#  'Please suggest me a laptop under 80k for an accountant with latest generations for long run use.',
#  'Nothing ear 2',
#  'Samsung buds live @ 4k',
#  'Nice deal thank you.',
#  'Nice deal',
#  'Pixel 6a @25499',
#  '@Laksh H samsung if u opt for emi on icici credit card',
#  'Should I buy Redmi Note 12 Pro at 21K or not...please suggest in terms of battery life, display quality and mainly performance',
#  'Please bring a video for smartwatches in budget range like 2000 to 8000 category. We love you a lot',
#  'iPad 9th Gen 64GB at 26k',
#  '\u200b@sameer shekhar Samsung or op?',
#  'Realme gt 2 @ 25K',
#  'Ipad 9th gen is also available 25990',
#  'Buds 2 pro 9k',
#  'Acer aspire 7 gtx 1650 i5 12 gen available at 48k and 16 gb for 52k<br><br>Asus tuf dash f15 at 66,500',
#  'Moto edge 30 ultra 44k',
#  'How you get 1750 Discount on galaxy watch 4 when its 10% discount? 12999*10% = 1299 not 1750',
#  'S20 fe is so outdated y do you guys recommend it?',
#  'Please don&#39;t put that text animation music in background, my head is paining after listening to that',
#  'Beebom never fails to impress..only the things which really matter. No prolonged video and stating actual price with separate additional discount. You guys rock.',
#  'Whats best smartphone for best camera under 50-60k?<br><br>Need for office IT professional  work  and personal camera for clicking birds, wildlife and recording videos sometimes..',
#  '@Akansha For that, you would be happy with Pixel 7.',
#  'What&#39;s best smartphones under 55k for office work and freelance work <br>Need best camera',
#  '@InternetUser04 Would Pixel 7 a heat less than S21FE and Pixel 7..<br>I need less heating as in my area temperature reach 40-45 degree<br><br>What&#39;s best under 40-60k?',
#  'Is there any best phone  under 55-56k or maximum 60k with great camera<br><br>Performance: little bit better than average<br>Need less heating as I live in area with high temperature<br><br>What&#39;s best?<br>Pixel 7<br>Vivo x90??',
#  '\u200b@Retro TechOnePlus 11r',
#  '\u200b\u200b@Retro Tech pixel 6a or 7.. or maybe wait for a little longer, pixel 7a is on the way and it&#39;s gonna have the best camera out of all, for about 40k.',
#  '@Retro Tech pixel 7',
#  'What&#39;s other best option that has camera better than Samsung S21FE..even by spending 10k extra<br>With less heating<br>Any recommendations under 40k for best possible camera<br><br>Or<br>Even under 50k for best possible camera<br><br>Less heatw',
#  'Kudos to you for using the usual price instead of mrp like some other channels',
#  'Anyone has any information(chipset and launch in India) about realme gt3 and gt neo 5se ?',
#  '@Akansha if you&#39;re willing to wait for a few days (till may 11th), you can see the pixel 7a pricing and all too. It will be priced higher at launch than at sales but might come with some launch offers like bundled pair of pixel buds and all so if you&#39;re interested in that. Other than that pixel 7a will go on diwali sale for around 30k so you could wait for a few months if you have the time and a functioning phone right now. Else the pixel 7 at 45k is not at all a bad deal and a pretty great smartphone for your use case',
#  '@Akansha can go with iPhone 13 (if on sale which usually comes at about 57k) or pixel 7 which is 45k rn and has almost the best camera performance along with pretty decent general performance too. S23 is out of budget and not that big of an upgrade from pixel 7 so yeah pixel 7 is the best deal at 45k for your use case if you don&#39;t do hard-core gaming (not the usual subway surfers or bgmi sessions but the intense genshin impact at 1080p ultra quality and all)',
#  'What&#39;s best smartphones under 55k for office work and freelance work <br><br>Priority camera and performance',
#  '@Being creative Need best camera',
#  '@Retro Tech you need to provide your use case and priorities too, every smartphone has one thing better than others',
#  '\u200b@Retro Tech oneplus 11',
#  'What&#39;s best smartphone under 60k<br>OnePlus 11<br>Pixel 7<br>Vivo X90<br>Iphone 13<br>Or<br>Samsung S23<br><br>Or should I wait for Nothing phone 2',
#  '@Eva girl most importantly.. enjoy the purchase 😉',
#  '@Being creative Thank yiu',
#  '@Eva girl a very good device indeed (if you can afford it). Battery life is better than the s22 series and I&#39;d highly recommend the s23 if you want to go with a Samsung.. else you can wait just a few days for the pixel 7a too. It is launching on May 11 and the specs are amazing (very close to a pixel 7)<br>64mp main + 13mp ultrawide + 13mp selfie, 90hz display, tensor g2 (same as 7 w/ 8gb ram), wireless charging, metal build, compact size (bigger than s23, very slightly smaller than pixel 7), good battery backup and a &quot;flagship-like&quot; experience that the pixels are known to offer and all of this for cheaper than the pixel 7 and s23 and other Chinese high end phones.',
#  '@Eva girl tbh that&#39;s better than both in overall terms (OneUI is OP, just a little less battery) but the price isn&#39;t within 55-65k (base starts at 75k)',
#  '@Eva girl isn&#39;t that 75k?',
#  'How is Samsung S23 base??',
#  '\u200b@Eva girl x90',
#  '\u200b@Eva girlI&#39;d go with the pixel and the pixel service centres have increased to 10 so there&#39;s that too',
#  '\u200b@Eva girl pixel 7 is better as it has better software and also great camera',
#  'Is there any best phone  under 55-56k or maximum 60k with great camera<br><br>Performance: little bit better than average<br>Need less heating as I live in area with high temperature<br><br>What&#39;s best?<br>Pixel 7<br>Vivo x90??',
#  'The Rog flow series is having quite nice discounts as well :) mainly the entry level x13 and z13 under 1 lac',
#  'Quality of content of Beebom videos is getting amazing day by day. Kudos to all Beebom team!',
#  'Thanks for letting us know about the bad deals as well.❤🔥',
#  'Now that&#39;s some quality content we ask from all the youtubers',
#  'Vivo X90 is a hypothetical phone model that hasn&#39;t been officially released yet, so there are no confirmed details about its features. However, based on the naming convention of Vivo&#39;s previous models, it&#39;s possible that X90 could be a premium or high-end device that comes with advanced camera capabilities.<br><br>If you&#39;re interested in purchasing a Vivo phone with good camera features, you can consider some of the company&#39;s existing models, such as Vivo X60 Pro+, which features a quad-camera setup with a 50MP primary sensor, a 48MP ultra-wide sensor, a 32MP portrait sensor, and an 8MP periscope telephoto lens. The phone also has advanced features such as 5-axis stabilization, 60x hybrid zoom, and 8K video recording.<br><br>Alternatively, if you have specific requirements for the camera features you need, feel free to let me know, and I can provide more tailored suggestions.',
#  'Beebom never disappoint ❤️🗿',
#  '@Savage Sounds 🗿🗿',
#  'PJ never disappoints 🗿',
#  'Havells Trimmer BT9010 available at 699/- , Usual price 1500 to 1800',
#  '@Shantanu Nipankar when sale is star i m a plus member so 1day before of sale start',
#  'Don&#39;t buy its a chineese rebranded shit',
#  'im not able to find it.. its expensive',
#  'It&#39;s showing 1400....🙂🙂',
#  '@Devan Singh in which site ?',
#  '@Devan Singh when',
#  'I bought it at 499 only',
#  'thanks buddy',
#  '@vishnu nair Jai Shree Vishnu, Jai Shree Ram Brother',
#  'I didn&#39;t get it',
#  'Link?',
#  '@Kishore B look at the cost of philips trimmers , cheapest one is also 800 ruppee+',
#  '@van ngir might come back. Wait for it. Or else go for MI trimmer.',
#  'It&#39;s Rs 1860 for me rn. I need a new trimmer badly 😭',
#  'Thanks bro',
#  '@Make Your life easy konse app pe bai',
#  '@Saif ✓ not appearing to me at this rate',
#  'Great deal bro.. looking for a trimmer for a long time.. got this one<br>Hope the seller is not ur relative who is worried about selling his stock out 😂',
#  'Ordered it bro <br>Hope this is best buy ever for me',
#  'Pawan .yyou champ..you work for havells i have seen you',
#  'It&#39;s 3-4 year old one, you sure it&#39;s good?',
#  'Misfit or this?',
#  'Just ordered it for 679₹. Good Recommendation.',
#  'Sorry guys its not worth it, bad quality.Nothing like philips trimmer.',
#  'Thanks bro, just ordered....❤❤❤',
#  'Main video se jyda tumahra recommendation better lgra 😂',
#  'Purchased dude. Thanks a lot🙌🏼🙏🏼',
#  'Thanks a lot of',
#  'Thanks bro, much needed deal',
#  'Thanks bro',
#  'Thanks Yaar <br>Ordered',
#  'I ordered, is this product worth buy?',
#  'How is it? Is it good?',
#  'Thanks purchased it 😊 justnow at 709',
#  'A huge thanks to beebom for this video. I bought S20 FE today!',
#  'The Galaxy watch 5 LTE was also available at 15,300 which was a great deal',
#  'All offers are pretty cool<br>My bank a/c balance is Rs 20.02 <br>It never makes me fool 😂',
#  'Mera balance 101 rupay ka hai <br>kal hi shagun mila tha',
#  'The ipad 9th gen was available at 25900 excluding 1750 bank discount, now it&#39;s at 27900',
#  'You are always really great❤, not like others who literally support the brand and actually start advertising for them',
#  'Beebom knows what consumers want. Amazing Video.',
#  'Biggest deal which you missed out was marshall Woburn 2 for 35k , usually its around 45k.',
#  'For your time stamp you deserve a subscriber bro 🖤',
#  'Realme gt 2 is also a great deal considering current offer price',
#  '\u200b@Eva girliPhone if you are in the ecosystem. Google if you want updates for longer period and some camera editing features. Samsung if you want a reliable Android phone which could be repaired and better resale value.',
#  '@Eva girl pixel 7 for camera and ui, samsung for overall decent and iPhone if ios',
#  'So Samsung base S23 or iphone 13 or Pixel 7 <br><br>What&#39;s option to choose under 55??',
#  '\u200b@ABHINAV SHAHVivo x90 camera is better',
#  'Look  At  The  Gyan  Therapy  Copying Others   Video  &amp;   The  Trowling  It is  Receiving   🤦  🤦',
#  '\u200b@Eva girl iPhone 13 is an obvious option to go for and if not comfortable with ios then iqoo 11 5g',
#  '@Eva girl why would you go for a vivo device if you are spending that much, opt samsung or google',
#  'Is there any best phone  under 55-56k or maximum 60k with great camera<br><br>Performance: little bit better than average<br>Need less heating as I live in area with high temperature<br><br>What&#39;s best?<br>Pixel 7<br>Vivo x90??',
#  'Lenovo legion 5 with 6 gb rtx 3060 and r7 5800h, 16gb ram, 2k display, Dolby vision 1.05L after applying cards it&#39;ll become less. It was available for 1L also for a few hours',
#  'Is there any chance it becomes available for 1 lakh again ?',
#  'Appreciate your content beebom! 😊',
#  'Apple Watch Ultra, currently at 75k, excluding bank offers. Generally it sells at 84k -90k.',
#  '@Mir Sayef Thank u',
#  '\u200b@Eva girliPhone 13?',
#  'X90 has a really good camera but.... don&#39;t know about heating',
#  'Is there any best phone  under 55-56k or maximum 60k with great camera<br><br>Performance: little bit better than average<br>Need less heating as I live in area with high temperature<br><br>What&#39;s best?<br>Pixel 7<br>Vivo x90???',
#  'What extension are you using to track the price?',
#  'Hello beebom team, can you please share the device release date next to the price so we can take an educated guess about how many years that device will recivr future security and android updates , it is a pain to search for those separately. Iam suspecting that all these discounts  are only for devices that 1.5 years old',
#  'Legends waiting for BBD 😅',
#  '@Aman mohanta sep',
#  'Kab hoga?',
#  '@Deeraj kumar September',
#  'When will be upcoming BBD sale',
#  '@shaik asif  mai toh emi pe hi leta hu.. 😂',
#  '\u200b@Ansh Agarwal they are not legend, they are le jhand',
#  'Me',
#  'Legends buy second hand products at cheaper price 😂',
#  '@Dark Knight bhai majak tha 😞🥲',
#  '\u200b@Dark Knight But everyone is legend 🗿',
#  '\u200b@Krish Bowlerwhy would you need a phone immediately.. unless your phone is broken',
#  '\u200b@Dark Knightyaar what about the demand of the product we need? How can we wait for months if we immediately need a smartphone 😅',
#  '\u200b@Ansh AgarwalYou get the best Value for Money in BBD.',
#  'Legends don&#39;t wait for sale they just buy it 🗿',
#  'Amazing Video!! To the point !! ❤',
#  'Great commitment to your subscribers to make this video...❤️',
#  'realme gt 2 at 25k is the best deal in my opinion',
#  'Galaxy Watch 5 LTE is available for 17.5k normally it fluctuates in 32k-36k range but you will need SBI card and maybe it user specific.',
#  'I got the redmi note 12 pro (8,256) for 19k by replacing my old redmi note 8, the phone itself was ₹5050, but there an additional ₹4000 discount for exchanging, which meant I am getting ₹9050 for a phone that I got for ₹13500 in 2020, it&#39;s a very good deal.',
#  'Bro you should have purchased realme gt neo 3t it&#39;s also available for 19k and way better than redmi note 12 pro',
#  '@Arjun C scary 😶\u200d🌫️',
#  'I was purchased redmi note 12 pro on March this year just used 10 days and I&#39;m  notice some flash autoturn off issue checked with service centre they said it&#39;s a motherboard issue my phone is in service centre more than a month now . No response from there  so I given a complaint on consumer court and it still going on 😤😤😤😤😤 be careful bro',
#  '@Priyanshu same bro. Up until redmi note 10.they were the best VFM phones and i have been using note 8 pro for 4 years now and it works good. No issues.',
#  '\u200b@S5TONIC bro sare milke tmko pagal bna rhe 😂<br>Redmi note series are by far the most VFM phones.<br>Been using RN 9 pro, it&#39;s great<br>MIUI is stable, no ads, tons of features like floating windows, gallery editor, I&#39;m just so used to it that I wanna stick to miui forever.<br>Cameras hv slow mo, micro which are the better than realme &amp; even OnePlus, (I&#39;ve compared them side by side)',
#  'Had been a proud owner of redmi note 11 pro and it got a mother board issue just after 3 months of the warranty completion. Good luck bro',
#  '@Giz Tech G\xa0 just go for s22 series phones<br>Trust me , stick with Samsung,  you will never regret',
#  '@Retro Tech Samsung s22 or vivo x80',
#  'What&#39;s other best option that has camera better than Samsung S21FE..even by spending 10k extra<br>With less heating<br>Any recommendations under 40k for best possible camera<br><br>Or<br>Even under 50k for best possible camera<br><br>Less heat',
#  '@S5TONIC\xa0 yeaa just don&#39;t do updates <br>I was also using redmi series phone<br>the note 10 pro max , and updations ruined my phone. <br><br>Currently I moved to Samsung<br>S21 fe',
#  '@papaya noted.',
#  '@S5TONIC you won&#39;t be able to use that headphone jack and consume your media after redmi gives you a software update to kill your motherboard so better not upgrade your phone in the future',
#  'Considering the fact I don&#39;t use my camera alot, plus I&#39;ve been using an old phone since 2020, it won&#39;t matter to me that much, I don&#39;t game as well, I got it cause of the stereo speaker because I consume alot of multimedia and the fact that it has as a headphone jack is a plus point for me too.',
#  'Welp , redmi is always redmi<br>RIP software',
#  '@Sanjay K Negi it&#39;s called the legendary &#39;&#39;Meme Ui&#39;&#39; for a reason 🥶',
#  '\u200b@papayayes, + buggy software 😂😂',
#  '@hm he&#39;ll cry after sometime😂 dead motherboard',
#  'i tried to purchase it. but there are 100 reviews with 1 star ratings saying that this phone hangs all the time and camera is average',
#  'Macbook air ‘1 was available onflipkart at 73k using sbi card offers',
#  'Thank you very much Beebom❤ Yesterday I have buy the Samsung Galaxy S21 Fe after watching this video it&#39;s huge deal for me as I&#39;m using My Samsung Galaxy J7 Max from 2017 and I exchanged it with 3k Rs in Samsung Shop. In 2017 I am a student and now I&#39;m doing my 1st job and I have buy this with my salary it&#39;s a huge achievement for me.❤ My J7 Max is in really good condition without any damage but battery backup is now going down. Thanks champ(J7 Max) for this 6 Years of Incredible Journey ❤️✨️',
#  'Is nothing ear 2 a good deal foe 8k. I am unable to decide between pixel buds pro at 13.75k and ear 2 at 8k😊 for my s23 ultra. I already have buds 2 pro. Looking for multi point connection as the first point.',
#  'Guys, pleade dont buy S20 FE 5G. It&#39;s too old',
#  'Use custom rom.. And still better than any 25k phone available.',
#  'Whats best smartphone for best camera under 50-60k?<br><br>Need for office IT professional  work  and personal camera for clicking birds, wildlife and recording videos sometimes..',
#  'Technology never gets old',
#  'My commenting from my 4 year old samsung Note 9,which works still like a charm❤',
#  'I want to buy s21 Fe in 2023. Is it good time?',
#  '@इशु You moron check your stats again, I am talking abt the S20 FE which was the starting one that came on 2021 and make your facts clear before commenting shit, the 2021 sets are getting only 3 years firmware updates and what i wrote there was the same. Baithe raho security patch leke agle 2 saal ke.',
#  'Please make best smartphone under 55k... no one touches segment between 45k-55k<br><br>Because for some video recording and clicking pics are important and performance equally...so the only segment left is 45-55k<br>If you can make video on that for best camera smartphone',
#  '@Amit Sarkar bro, a flagship exynos is still leagues better, especially with OneUi.<br>if you&#39;re not a mobile &#39;gamer&#39;, the experience alone is worth it.',
#  '@Pranay Biswas lmao, it will get updates till 2026 you doofus. 4 years of OS updates, 5 years of security: phone launched in 2021 -&gt; 2025-26<br>how many years your precious Realme will give?<br>also,<br>if you use a phone for &quot;gaming&quot;, lmao. good camera, software, stability gaya bhaad mein, let&#39;s do gaming.',
#  'But it&#39;s better than galaxy j3 ☺️',
#  'Yes correct',
#  'The only issue with s21 fe is Exynos... S20 fe comes with snapdragon. The pic quality is too good and some even turn up better than pixel 7.',
#  'You can choose alternative s21 fe',
#  '@Sahil Hussain you will get pixel 6a just little bit 3k+',
#  'agreed',
#  'Yes!! It&#39;s way too old, software support might end by next year!.',
#  '@Soma Halder yes... That sucks',
#  'Main problem with S20 FE 5G now is old small battery',
#  '@Akansha red magic 8 pro vangiko.. Best',
#  'What&#39;s best smartphones under 55k<br>Need best camera',
#  'Sure noted',
#  '\u200b@TheUjjwalarora realme has by far the worst optimization. Open the camera app and wait for 10 seconds for your phone to work properly',
#  'Ye s20 fe and s21fe ko jo king holta h na wo oppo or vivo wale hote h real life me...  <br>Saala dono phone ka battery 5 hour backup deta h bas , I😂😂😂😂',
#  'Non take... I&#39;m taking more about practical use as S20FE has non left! I guess just one more update left?',
#  'Still better than a lot of competitions',
#  '@Ayush Kumar yeah my bad, but still it&#39;s too old',
#  '@Abhinav Goswami S20FE 5G launched on 2021',
#  '\u200b@Ayush Kumar FYI, that&#39;s already over mate... It&#39;s a 2020 model, it&#39;s 2023 now, u ain&#39;t getting anything',
#  '\u200b@Ayush Kumar and I prefer S23 ultra 😊',
#  'Yep. S21 FE is far better right now.',
#  '@TheUjjwalarora No disrespect but Samsung S series and Realme is class apart. You must use samsung One UI (One UI for M Series and S Series is different). Camera and Software experience can not beat at this price.<br>And I doubt Realme will keep there promise of Software Update.',
#  'S20 FE is king 👑 at this price level<br>Decent camera, Storage capacity, snapdragon processor 👍 <br>Only battery is below average 👎',
#  'At 24k i suggest Realme GT 2, it&#39;s a flagship with 3+4 yrs Android update plan.',
#  'Still better than most of the phone at that price. Plus u still have 2 year of Security Update and One Major OS Update.<br>For someone who wants phone for Media consumption and Camera it is best in class.<br>Ps I personally would prefer S21FE 😅',
#  'Yeah agreed 👍',
#  'Most impressive Beebom always... Never skip while watching... Love from Chennai',
#  'i chose vivo27 for my mom, camera centric, s21 fe was my first choice but read about a lot of the heating issues and bad battery backup with the exynos chip, so stayed away. <br><br>One thing with vivo27 is the bloatware, which I&#39;ll happily remove via adb, so i guess it&#39;s a great deal at 31k, what say peeps?',
#  'We are buying s21fe for my mother. Checked out v27 too but my father said 30k is too expensive for a Vivo phone and curved display would be fragile😅😅',
#  'good to know that you removed the bloats with adb finally some smart smartphone buyer for family',
#  'Bro you could have also included tablets as well',
#  'No bs straight to the point…👏🏻',
#  'Pixel 6 pro at 43K is sweet deal. But 43K is now constant',
#  'I miss the old Beebom intro! Please bring it back 😔',
#  'POCO F4 12GB RAM &amp; 256GB ROM available at 27499 is a great deal it seems. Also comes with a 2 years warranty.',
#  'Heating issue otherwise it&#39;s good',
#  'Very poor camera quality',
#  'I like how this channel creates comparatively short videos with accurate content',
#  'superb video, but we do look forward products below 5k!',
#  'no fillers, no bakwas... direct to the point... hats off beebom',
#  'the s21 fe  bank discount of hdfc is for normal purchase or emi  on samsung website? i dont understand',
#  'ya but S20 Fe is kind of really old right. the chip support from qualcomm could be another area where clarity is required.',
#  'I bought Galaxy S20FE in February this year and it still works fine and competes with the latest launches. <br>And the best part is that I got an Android 14 update yesterday.',
#  'You&#39;re doing a great job',
#  'Wonderful work ❤',
#  'Is one plus buds pro 2r available at 9K a good deal.?',
#  'Much awaited 🔥',
#  'Galaxy Watch 4 LTE - Effective Price will be Rs 11,249 (not 10,249 as u hav mentioned)',
#  'OnePlus  Bullets wireless Z2 current price is1599 usuall it goes around 1799 it is good neckband❤',
#  'no🤫oppo enco buds 2',
#  'Make more such videos please!!❤',
#  'Acer Nitro 27inch monitor is available just for 13.5k, great for gaming with 165Hz Display. usual price is upwards to 16k',
#  'Which extension was it you used to track the price',
#  'That&#39;s amazing😍😍😍',
#  'realme gt neo 3t will be back in sale or not?',
#  'Pixel 7 PRO is at a much better discount+ Deal at the moment.<br><br>Pixel 7 was already available at 45000 is this offer this time is not any better.<br><br>Pixel 6A is available at around 26K after all discounts.',
#  '\u200b@Eva girl S22+',
#  'The problem with the pixels are the terrible service availability, even the service rates are extremely high.',
#  'Is there any best phone  under 55-56k or maximum 60k with great camera<br><br>Performance: little bit better than average<br>Need less heating as I live in area with high temperature<br><br>What&#39;s best?<br>Pixel 7<br>Vivo x90????',
#  'How additional discount of 1750 makes a 13k watch 10,249 ? Beebom needs to practice math😂',
#  'Awesome work 👍',
#  'Hey, what&#39;s the price graph extension ?',
#  'Always on point and great video. Appreciated. Buyed Galaxy Watch 4 LTE version at 12K.',
#  '@Deepak Bisht hahah😂😂 just waise hi pucha tha.',
#  '@Nisar Ahmed 😂😂 kuch nai milta. Kaash mil jata toh side business ban jata.<br>Are Bhai Dil pr mat lena.<br>Bus rok nai paate khudko jab aaise cheje dekh jaate h. <br>Have a great bruh!',
#  '@Deepak Bisht ho jata hai bhai jaldbaaji me. English correct karke waise milta kya hai😂😂😂',
#  '@Profound its pretty good but i didn&#39;t liked the battery backup.',
#  'Bought not buyed 🤦🏻',
#  'Please do share your experience',
#  'Very Helpful Video, Thumps Up<br>Please make this type of video in the future too. It helps to buy products wisely.',
#  'Realme GT 2 for 25k getting snapdragon 888<br>Also realme GT 2 PRO for 35k for 8gen 1 and 2k display',
#  '<a href="https://www.youtube.com/watch?v=3MZ6aTpFrE0&amp;t=1m03s">1:03</a> <br>Your math is blowing my mind.<br>Anyways video is direct on point no bs,  thumbs up for that.',
#  'I was about to comment the same Bhai 😂',
#  'Nice observation, yes a small mistake with calculation',
#  'Samsung Galaxy Buds 2 Pro is generally around 15k to 18k. But right now you can get it under 12k. Some people get it under 12k also',
#  'Got it for 9.5. its available even now for 11k with 5k discount',
#  '@Saksham Bindal bro check',
#  '@Ayyan\xa0 I have Amazon pay ICICI card. On it showing discount of only 5700',
#  '@Saksham Bindal now it&#39;s showing me 6500 for full payment and 6700 for emi. Check again',
#  '@Ayyan\xa0 oo.. I ws checking the deal then too.. maybe I missed it',
#  '@Ayyan\xa0 ok. I am only getting 5700 discount 😅',
#  'Amazon offered extra coupons for prime members and it&#39;s not available right now',
#  '@Saksham Bindal no normla icici card',
#  '@Ayyan\xa0 Which card did you use amazon pay ICICI ?',
#  'Bought in amazon early deals before sale at 7256 instant discount with icici card and 600 no cost emi discount.',
#  '@Ayyan how?',
#  '\u200b@Ayyan  how ?',
#  '@Ayyan bro what, really, when? Buds 2 pro?',
#  'I got for 8k in amazon',
#  'One should go for Pixel 6a at 27k instead of Samsung s20 fe',
#  'You guys know the pulse, don&#39;t you? Awesome Quick Video',
#  'Quality content.',
#  'iPad 9 gen is only at 25,900❤❤❤❤ its a really gr8 deal if you want to buy budget iPad.',
#  'But it&#39;s 23k in amazon',
#  'HP Omen 16 (Ryzen 6800H + RTX 3070 ti) at 1.15L is a really good deal on Amazon',
#  'Need to check wattage limit on that GPU then buy',
#  'That&#39;s the cheapest 3070 Laptop!!!',
#  'I bought Motorola edge 30 pro at 30k a month ago. Still couldn&#39;t find a better deal at that price range in these sales. Hands down',
#  '@vibrio cholera thank you',
#  '@Eva girl Go for OnePlus 11. VIVO X90 is not that great, VIVO X90 pro is the best. <br>I personally don&#39;t prefer pixel phones owing to the lack of service centres in India. <br>If you can take the risk pixel 7 would be the best choice.',
#  'Is there any best phone  under 55-56k or maximum 60k with great camera<br><br>Performance: little bit better than average<br>Need less heating as I live in area with high temperature<br><br>What&#39;s best?<br>Pixel 7<br>Vivo x90????',
#  'hey should I go for the pixel 6 pro at 45k',
#  'What is the chrome extension you guys use for keep track of prices?🤔',
#  'Price history 🤫',
#  '@Ximnani Thanks.',
#  '@Eva girl pixel 7 or iphone 13',
#  'Is there any best phone  under 55-56k or maximum 60k with great camera<br><br>Performance: little bit better than average<br>Need less heating as I live in area with high temperature<br><br>What&#39;s best?<br>Pixel 7<br>Vivo x90???',
#  'keepa',
#  'buy hatke',
#  'Please make best smartphone under 55k... no one touches segment between 45k-55k<br><br>Because for some video recording and clicking pics are important and performance equally...so the only segment left is 45-55k<br>If you can make video on that for best camera smartphone',
#  'Hey I got Samung galaxy buds2 Pro for 9500/- . It was going for 15999 , then i had 6500 icici card discount (5000+ 1500 prime). Its the best deal and it got delivered just 1 hour ago!!!!',
#  'when you say trust me i be like i dont trust someone who doesnt look me in the eye😂😂😅😅😂😂',
#  'Perfect video!',
#  'There is around 18k off with SBI Credit Card on Samsung Galaxy Book... Please cover it if possible...',
#  'Redmi K50i normal prize - 23/27k<br><br>Current price - 21/24k',
#  'Really need to buy that realme gt neo 3T....but have to wait for some months due tm some financial situation....i hope september ki BBD me aur discount me available ho jaye..then might be 🤞',
#  'Realme GT2 at 23k with exchange bonus &amp; card discount. Actually only 2k more than the Realme GT Neo 3T at 21k for the same 8-128 variant',
#  '@Rahul Sadhu when I can buy new for 23k? Think &amp; talk',
#  '@Rahul Sadhu What&#39;s your experience bro',
#  'Buy from me 6 months old at 22k',
#  '@Rithu Gokul K No bro, I have used the device and played games for more time. My friend bought that device and I also felt the same but after my long usage I changed my opinion that it far far better than other SD 888. Now I think my comment makes some sense ✌',
#  '@Steven SJ I would 100% take your opinion if you&#39;ve actually used the device. Since neither of us did, I&#39;m going with the general internet conscience that 888 is less optimised. And this specific case gt neo 3t is a better buy than gt 2 with little to no lose in perfomance department.',
#  '\u200b@Rithu Gokul K just check the reviews of that phone due to its cooling system that&#39;s not heating as other 888 processor phones and it&#39;s not even throttling in CPU throttle test...see the reviews and talk bro',
#  '\u200b@Rithu Gokul K its good lol',
#  'comes with an inefficient chipset which everybody basically gave up on',
#  'Please make the best laptop deals for every user type.',
#  'The plugin which Beebom used to check price : Buyhatke - Price Tracker',
#  'Already ordered S21FE yesterday , excited to see it, purchased it at 30k',
#  'Those complaining about battery check out the capacity and then speak <br>Noone will have any issues with battery',
#  'VNR ravali kadha thanks',
#  'Did the order in transit i book day before yesterday delivery was yesterday till today the item was not picked up by the courier service',
#  'Is there any best phone  under 55-56k or maximum 60k with great camera<br><br>Performance: little bit better than average<br>Need less heating as I live in area with high temperature<br><br>What&#39;s best?<br>Pixel 7<br>Vivo x90??',
#  '@Tharun muddapu thanks,  I&#39;m using it right now , such a great display',
#  'Good purchase 👌🏻',
#  'Battery life is bad 😢',
#  'You&#39;ll love it dw. I&#39;ve been using it since the BBD sale. Battery can be an issue with 120Hz on a heavy day. Otherwise it&#39;s all good.',
#  'Battery life is very poor brother..<br>Camera is very good..<br>There are frame drops here and there',
#  'But isn&#39;t gt2 pro a better phone?',
#  'Asus Vivobook 16 pro that was a crazy deal 🤝',
#  'can anybody tell what extension he&#39;s using to compare the price changes?',
#  'It&#39;s Buy Hatke',
#  '@Sumrit Chamber thank you',
#  'Pricetracker, pricehistory, keepa .. any of these will work to track the price of any item.',
#  'Waiting for bbd for laptop earbuds and headphones 🤌🙂🌝',
#  'samsung galaxy book 3 i5 13th gen is available at 53k now against usual price of 74k🔥🔥🔥🔥',
#  'One of the best deal of this Sale.',
#  'Could you please share where this deal is available?',
#  'Can somebody pls tell me how to get the S21 FE for exactly 30k, which offers/coupons should I apply',
#  'My Friend was waiting for sale so that the OnePlus 11R will get a discount but there are no discount on One Plus devices. He has been waiting for weeks to get a discount but Today we are casually roaming around the mobile stores, I just asked how much is One Plus 11R? He said 37999.I asked about the higher variant and he said 42999. I immediately told my friend to get the device. He bought it at 42500. Currently it&#39;s available for 45000 on Amazon. We got a free case worth 350. Sometimes I feel one must check local stores too.',
#  'Frr Bro, I was dying to buy the 11r. But This mfkin sale spoiled my all intentions and excitement. I think it&#39;s better to go to offline shops to get it',
#  'Its new phone so dont expect a discount for 3-4 months',
#  'Never scene like this.... Lot of information within very short time. Thanq so much',
#  'S21 FE deal looks the more tempting.',
#  '\u200b@Sri Prakashya same issues with P 6a ...',
#  'Guys if you&#39;re not a heavy gamer this is the best phone for this current deal . The cameras are remarkable',
#  '@Shubham if u are not a gamer I will suggest s21 Fe it&#39;s good',
#  '@Sri Prakash OK thanks... I was confused between s21 fe and realme gt2.... s21 fe just because of UI, video consumption and updates.... gt2 coz of sd888 and price.... i want a phone for daily tasks and not gaming and want the phone to last for at least 3 years... which phone should I buy?',
#  '@Shubham it should last but the only thing concern is Exynos we can&#39;t rely say how it will age depending on the past experiences but I think it should easily last 3 years minimum',
#  '\u200b@Sri Prakash will this phone last for 3 to 4 years without any repair?? considering I am a casual user for Day to day tasks and for video consumption and not a gamer',
#  'Deal is amazing I bought at 32k last year sale with card discount, now it marked at 32k... so.. great price.',
#  'Don&#39;t buy it for battery. I use 5G at 120Hz, battery drain like hell, I get 3 hours SOT',
#  '@Sri Prakash ok thnx , I really like it but worried about poor performance and battery due to exynos',
#  '@Piyush Gupta battery life is kinda avg i will say getting around 5 - 6 hr sot if we use phone on 120hz it will decrease faster',
#  '@Sri Prakash and how is battery life, how much sot u getting',
#  '@Zain ha it had some heating when using camera for long period otherwise no heat',
#  '@Sri Prakash how is it so far? Why do I keep hearing about the heating problem 😕',
#  'Commenting from s21fe🤟',
#  'What&#39;s that price tracker you guys are using...?',
#  'you shoud&#39;ve added samsung tab s7+ which is available at just 45k',
#  '@Pankaj Sharma September',
#  '@Pranav kab aayega bbd',
#  'Bbd 40k',
#  'How often you guys are replacing old phones? I completed 2 years with my Realme 8 and I&#39;m feeling to keepi it for an another year. Presently, very few phones are worth buying. Only realme 3t looks good.',
#  'VNR ravali kadha sure mate. Take advantage of card discount.',
#  'VNR ravali kadha Bro if your usage is minimal, then don&#39;t spend 30k.<br>15k pe bhi mil jayegi.<br>Realme 10 dekh sakte ho',
#  'VNR ravali kadha Google ui is pure android. No bloatware.<br>But Samsung one ui is clean but not like pixel.<br>Better than other roms. Battery is a concern in s21 fe.<br>Rest are good.<br>If you want good battery and charging speed then Chinese phones stand out more',
#  'VNR ravali kadha I would go for s21 fe, camera is good here too.But if you are a strict clean android fab then 6a will be good.',
#  'VNR ravali kadha It was, initially. But they improved it a lot better with constant updates.<br>They had to focus on only one phone and they did get it right with updates.',
#  'VNR ravali kadha Camera is good but battery is the worst.. charging is slow. Better consider nothing 1, Samsung ones.',
#  '@Shubham Mu pleasure bhai',
#  '@Soumalya Paul OK thanks bhai',
#  '@Shubham Don&#39;t forget to use card during purchase',
#  '@Shubham I think s21 fe will be a better bet. If they are promising till A16 then go for it.',
#  '@Shubham S21 fe ka battery bekar hai. Aur sab top notch. Realme bloatware ke alawa aur sab thik hai. Nothing 1 dekh sakte ho',
#  '@Soumalya Paul Yeah, thanks man. I&#39;ll check them out.',
#  '@Soumalya Paul I think it will get updates till A16 as per the official announcement.... so which one should I consider? realme gt2 or samsung s21 fe?',
#  '\u200b@GCS YT how was it free im using 7t and the battery has degraded alot over the years',
#  '@GCS YT Legend 😉',
#  '@Saurabh Srivastava Then I don&#39;t see the need to spend much on smartphone. You can consider the ones I have recommended.',
#  'My oneplus 6 will complete 5 years in 3 months. I don&#39;t feel like upgrading. Replaced new battery 1 year ago for free of cost at at Oneplus service center. Still runs good for daily tasks. I&#39;ll use it for one more year.',
#  '@Soumalya Paul Yeah, for me, a phone is just a communication device, Whstappp, Instagram and banking apps, only these I use on phone, for the rest of the tasks, I prefer using laptop so spending much on phone doesn&#39;t make sense to me.',
#  '@Shubham Could have recommended Moto but since you will be using it for 3 years then it&#39;s a big no. Moto ke updates you know bohot bekar hai.<br>Samsung A34 bhi thik hain. S21 fe bohot purana hogaya hain. Abhi kharidna sahi nehi rahega. Sorry about that A15 tak update milega wala statement',
#  '@Shubham My experience with Realme has been good. Wouldn&#39;t say outstanding. I got 4gb ram wala variant which I regret till date. Always opt for 6gb and above. Phone has hanged quite a few times.<br>Since I&#39;m a casual user so the experience has been okayish. I plan to keep it for an another year since A13 will come and that will be the last os update.<br>Coming to your kaunsa phone buy karein, Realme abhi bohot bloatware bhar ke de raha hai. Aur your budget is 30k so you have multiple options.<br>You can look at Nothing 1.<br>Wouldn&#39;t recommend Pixel 6A.<br>S21Fe is a good one too. I believe you will be covered till A15.',
#  '@Saurabh Srivastava Quite a tight budget. Only two phones come to mind.<br>1. Realme GT neo 3t<br>2. Redmi k50i',
#  'hi how is your experience using realme? actually I was confused between realme gt2 and samsung s21 fe.... S 21fe just because of its UI, video consumption, android updates and premium feel..... whereas realme cause of snapdragon 888... i am bit worried about realme ui which has alot of bloatwares and ads and also realme gt2 is kind of sidelined by Realme themselves so don&#39;t know whether it will receive timely updates....... Can you please suggest which to buy considering I am a casual user for Day to day tasks and won&#39;t be gaming and want the phone to last for at least 3 years',
#  '@Soumalya Paul I am looking for a phone in between 15 to 20K.',
#  '@Saurabh Srivastava I can help in case you need an additional help.<br>How much is your budget? Preferences?',
#  '@Soumalya Paul Yeah, definitely. I am actually looking for a phone from last 2-3 month, though could not zeroed my search on any particular phone.',
#  '@Saurabh Srivastava Updates have stopped and might have slowed too so I think it&#39;s high time to go for a new one.',
#  'As long as the battery doesn&#39;t cause an issue, I keep it. My current phone was purchased 4.5 yrs ago which is now due for replacement.',
#  'If the asus vivobook pro had good battery life I would&#39;ve purchased it instantly',
#  'Very informative video 👍',
#  'Suggest a overall good neckband under 3k or 2k',
#  'Sony WI-XB400, downright amazing! I&#39;ve used multiple gens of OnePlus&#39;s neckband, and this wipes the floor with them. Has less features and a rather worse look, but cannot beat it in sound quality or mic',
#  'oneplus best',
#  'Mad deal- hp omen 16, 6800h+ 3070ti @ 115k on Amazon. If i had the money then i would buy this laptop without any second thought',
#  'Which extension or software you use for price history?',
#  '@Sanket Sharma Thank you so much',
#  'Keepa for Amazon',
#  'Idk how at <a href="https://www.youtube.com/watch?v=3MZ6aTpFrE0&amp;t=1m00s">1:00</a> with 1750 discount 12,999 becomes 10,249. You might need a new calculator.',
#  '&quot;Give me the definition of Unhealthy love&quot;<br><br>&quot;Beebom and S20 FE, launched 3 years ago&quot;<br><br>&quot;Pefect&quot;',
#  'Not recommended now with Android 13 probably the last one. Better go for S21FE even though Exynos 2100 😮',
#  'Using an S20FE since 8 ish months now and I have faced 0 issues with this phone, unbelievable device for real. But I&#39;ll recommend people to go for the S21 FE instead as it will last for more years in comparison.',
#  'Its working perfecfly fine and got android 13 update already....camera...IP rating, wireless charging, one UI and decent processor...still an steal deal for 25k....',
#  'Still amazing phone',
#  'Commenting from s20 fe 😎',
#  'Still a good deal imo under 25k',
#  'How long does this summer sale last?',
#  'Don&#39;t buy the S20 FE people. It&#39;ll no longer receive Android updates apart from a couple of security patches. There&#39;s literally no point in investing in a 3 yr old processor even though it&#39;s a flagship one. I really can&#39;t wrap my head around getting a 28K phone with no updates. It&#39;s beyond me why YouTubers continue to recommend it, especially Beebom.',
#  '@Kuriakose Kurian Ambat no one gives a damn about your real life experience when the phone has completed its update cycle of 3 Android updates. Only security patches will be released from now on.',
#  '@Ramneek Singh I am replying with real life experiences, not with just google data. So kindly do your research first.',
#  '@Kuriakose Kurian Ambat this one ain&#39;t getting any more Android updates since it was launched on Android 10 and Samsung promised 3 updates i.e. Android 11, 12, 13. That 4 year policy came into place after the S20 FE was launched. Go check your facts first.',
#  'S20 FE still receives android updates and is currently running on One UI 5.0 which itself is the latest update rolled out. Samsung offers 4 year android update and 5 year security updates. This phone was released in 2021 , which means it will continue to get updates for another 2 yearw and 3 more year of security updates. <br><br>It&#39;s a good deal for sure🎉',
#  'The 15W charger in box despite it supports 25W charging 😖',
#  'How about moto edge 30 ultra going for 40k',
#  'I actually got the nothing phone 1 8gb 256gb at 27200 <br>With the SBI card offer that too on no cost emi <br>So does it count ? <a href="http://www.youtube.com/results?search_query=%23beebom">#beebom</a>',
#  'I don&#39;t know why nobody talks about the Realme gt2, it&#39;s got a snapdragon 888 processor, a sony IMX 766 sensor and it&#39;s going at a prize of 24999 WOW 🤯',
#  'Steal !!',
#  '@sakshi chaturvedi I am planning to buy the same smartphone, because I think it&#39;s the best device under 25k, considering it&#39;s supposed to get the Android 15 update, making it the only (about an year old ) device to be that way. Hopefully gonna buy soon 🙏🏻',
#  'Ordered it yesterday waiting for it.Hope made the right decision.',
#  'Samsung s20 Fe or S21 Fe, for minor gaming and good camera. I don&#39;t want to go for Iqoo but i am open to it if the camera&#39;s are good.',
#  'Pixel 7 is listel at 44k on Amazon excluding card discounts',
#  'Trust me. Don&#39;t buy the s20 fe. It&#39;s 2 years old already. Phones should not be bought any later than 1 year after launch. No matter how good they are',
#  '@NISom SOM they are talking about 5g version only, ig',
#  '@अभय अग्रवाल only the 5g version right? And that&#39;s more expensive',
#  '@NISom SOM it has snapdragon 865!',
#  'Exynos 990 is also pretty bad, s21 Fe is much better',
#  'Broski the phone is superb! No problem if it won&#39;t get updates anymore.<br><br>Chinese phones with shit cameras &amp; shit ui which lags on day to day tasks, and recieves updates very late, which results in motherboard dead 🤧<br><br>S20 fe is a much better deal.',
#  'I&#39;ve purchased VivoBook pro 14x oled<br>Now waiting for the delivery 😊',
#  'Very clear video on deals <br>Make like this video on every sale please',
#  'Don&#39;t buy S20 FE FFS!',
#  '@Ꮪᴀᴛʏᴀ Then maybe you should go for Realme or iQoo phones in the budget. Also there&#39;s not much price difference currently between s20fe and s21fe',
#  '@Shalin Shah what if someone can&#39;t increase the his /her budget.',
#  '@Ꮪᴀᴛʏᴀ You can buy s21fe with just 3 or 4 thousand more, it&#39;s a better choice. I bought it just yesterday.',
#  '@Shalin Shah but still good, in camera, good processor, display, design and etc',
#  '\u200b@Ꮪᴀᴛʏᴀ too old now',
#  'Whybro',
#  'any comments on the google pixel 6a for 28k?',
#  'What about the moto edge 30 ultra?',
#  'Pixel 6 pro available at a price of 45k. 2y old but Good to go as it&#39;s pixel',
#  'Kudos bro. This helped to save a lot of time. <a href="http://www.youtube.com/results?search_query=%23beebom">#beebom</a>',
#  'How can I see usual and sale prices in a chart like you?',
#  'Hello Sir, please help me to choose phone under 19k i hv bajaj emi card n only realme 10 pro is available for 19k on this card i wanted to buy Narzo 50 pro, or z7 5g but they&#39;re not available in emi card so can i buy Realme 10 pro for 19k ? Is it good for 3-4year usage?',
#  'I got the apple watch series 8 deal for around 30k. Fantastic deal',
#  'I am using buy hat ke, compare hat ke from last 10 years . always gets best deals.',
# ...
#  'S20 Fe in 2023.?',
#  'Asus k15 16gb vs Asus 16x 16gb (5600h one)',
#  'Crompton 100L Desert cooler is around 9,500 after card discount',
#  'Should I get Samsung S21 fe now or wait for BBD?',
#  'S21 fe under 30k is s great deal imo. Go for it',
#  'It&#39;s very tempting but I will hold out for the pixel 7a',
#  'Yes you can for 30k its a decent deal. Also do checkout iqoo neo 7 that phone is superb for the price 28k after off',
#  'I bought a Pixel 6a for ₹25,500.',
#  'Stock video king 😁',
#  'Pls don&#39;t mention extra discount messes',
#  '@basharat true',
#  'Just ordered second S21 fe for my dad',
#  'I bought S20 Fe at 24k is it worth it? If you could let me know I will be grateful. ;(',
#  'Fe is series is closed dont get fooled',
#  'It will not get any updates bro then still people are buying it don&#39;t know why it&#39;s even still in stock',
#  'Moto edge 30 ultra almost 10k slash now available for 44999',
#  'Can you please uombal in the bathroom goodhole',
#  'Kindly recommend a good external hdd?',
#  'Real me gt 2 shi h kya 24000 heating issue to nhi h na bus m',
#  'Is galaxy buds 2 pro 11k a good deal?',
#  'Hey  beebom! GALAXY BUDS live are available for 4999, is it a good deal vs others at same price',
#  'Hp omen 16-n0123ax ryzen 7 6800h and rtx 3070ti available at 1,15,000',
#  'Pixel 7 is available for 44k and pixel 6 is  available for just 34k on Amazon',
#  'Oneplus 10r ar 31k',
#  'What&#39;s your view on goggle pixel 6a',
#  'What is the name of the plugin for price graph??',
#  'buy hatke',
#  'Samsung smart watch 4 after discount it&#39;s 11249 and not 10249 according to your video',
#  'Hey guys, except Samsung S20FE, others deals are good enough. I had S21FE in last year (@32k) and now bught Realme GT new 3t @18k (in 6 month No Cost EMI)...',
#  'following beebom for a looong time',
#  'Meanwhile, me missing the intro music',
#  'S20 FE 5G already at the end of update cycle, a good deal? How come?',
#  'Does anybody know the name of that historic price graph extension?',
#  '@stephen r thanks',
#  'buy hatke',
#  'Good Evening Bee 😁',
#  'Wo missed Google pixel 6A',
#  '1st view ❤',
#  'Sir how do you check price graph ?????',
#  'Got galaxy watch 4 classic LTE for 16k @Amazon',
#  'How to avail the 7250/-  bank discount on emi in the asus vivobook pro  16 ??',
#  'That end sound is scary in dark',
#  'see asus vivobook s14 oled, original is 70,000 but now it&#39;s available for 58k',
#  'Can somebody tell me how is he traking the price ?<br>M talking about the last part OnePlus price track.',
#  'Extensions',
#  'But Pixel 7 price on Amazon is 44k',
#  'Sir...please review of OnePlus Nord ce3 lite',
#  'Why the heck is s22 ultra price not dropping!',
#  'What about Asus tuf laptop ? <br>Is it in big deal ?',
#  'X90 pro vs iPhone 13 camera comparison <a href="http://www.youtube.com/results?search_query=%23beebom">#beebom</a>',
#  'New a video on vivobook pro 16 dedicated',
#  'How to avail the emi offer of 7000/- on the vivobook pro 16???',
#  'Slim and good battery life ASUS TUF Dash F15(2022) and if you want super power then go for DELL G15-5520 both are at 66,489 after bank discount. Best laptop under 70k. Thank me later 😌😊',
#  'Realme Gt 2 is also great budget flagship killer device available at 25K.',
#  'I buy apple Watch 8 series last week for 40k i think I want to wait for a week',
#  '@Arpit Verma apple Watch series 8',
#  'Which one?',
#  'Pixel 6a',
#  'Pixel 6a',
#  'How do you see the price graph?',
#  'buy hatke',
#  'there are third party extensions for that',
#  '25 k real gt 2',
#  'Galaxy buds 2 pro for 9500 <br>Go for it guys🎉🎉',
#  'Check return on those Apple Watch deals',
#  'Oneplus 1₹ deal 😂',
#  'Is s21 FE a good choice??!',
#  'Samsung galaxy Buds pro 2 with bank discount available at 8480rs which is the best deal the OnePlus buds.',
#  'Samsung galaxy Buds pro 2 with bank discount available at 8480rs which is the best deal the OnePlus buds.',
#  'So many amoled smartwatches are available below 2500.',
#  'Realme gt 2',
#  'First comment love you Beebom',
#  'I cant find the deal of galaxy watch 4 lte of 12k😢',
#  'hey beebom, which browser extension is that?',
#  '@Saurabh Srivastava not available on Firefox 🥴',
#  'BuyHatke',
#  'मुझे भी जानना है 🤧',
#  'Ayooo you forgot Samsung ear buds 1 for 4k❤',
#  'How is vivobook pro and vivobook k15 oled for video editing and photoshop ??',
#  'Poco x5( 6 - 128) at 15000 with bank offers',
#  'Noise Evolve 2 Smart Watch Is Available At 1799 Rupees<br>A Great Deal For An Amoled round Dial Smart Watch !',
#  'Nothing bud is on thumbnail but not on video.',
#  'Ipad air 4',
#  'Sale kab se suru hone wala hai',
#  'Yaar tumlog budget deal bhi toh batao. Maximum log budget deal janana chahte hai.',
#  'Are you kidding!!! ASUS VIVOBOOK PRO 16 still showing 84K price tag',
#  'Not as many interesting phones in midrange as last year',
#  'You got card discounts wrong. Its 10% upto 1750 not fixed discount of 1750.  So galaxy watch,AirPods Pro and one plus earbuds would cost more.',
#  'Samsung galaxy tab S7+ @ 44999 ❤',
#  'Oppo enco buds 2 at 1599 <br><br>Normal price 1799',
#  'Tablet deals in apple and Samsung',
#  'Nothing phone 256 gb is on sale…..I managed to buy mine for 30500 and that too the white variant .',
#  'You missed samsung buds live.',
#  'Recommending Samsung S20 FE is not a good idea as it is two years old and has a three-year-old chipset.',
#  'Where is GT 2 pro?? its around 35k..',
#  '4 din sale ka wait kiya soch ke oneplus 11r pe achhi deal milegi but Amazon walon ne toh bs ₹1 ki deal de di 🥴',
#  'Real me gt 2',
#  'I understand that yout team istrying to suggest the best deals but suggesting an 11th gen laptop is not in the best interest of any of the viewers. <a href="http://www.youtube.com/results?search_query=%23asusvivobook">#asusVIVOBOOK</a>',
#  'Should I buy asus k15 oled R5 5500U 16gb ram @40k ?? Please tell anyone',
#  'i bougt 8gb asus oled for 51',
#  'yes 16 gb 512 at40 with oled is a steal.',
#  'Redmi K50i is a good deal',
#  'Man, Your expressions in the Thumb, scared me hell out…😅😅😂',
#  'Redmi note 12 pro+ is available for 27k with bank discounts , really really good device at that price....',
#  'Beebom is one of the best channels in yhe universe. Hence i calll myself a tru beebomer',
#  'Acer Aspire 7',
#  'Pixel 6A or S21 FE?',
#  'Checkout asus s14 intel evo i5  with h series 12th gen processor that is a beast under 60000',
#  'What about pixel 6a',
#  'Samsung buds 2 for 6.5 k without card offer',
#  'Airpods 3 are available for the mentioned price not airpods pro.',
#  'Ambrane wise glaze smartwatch no one is covering it amoled calling smartwatch at just 1427 crazy deal',
#  'I don&#39;t know why youtubers recommend emi because it&#39;s loss for the customer with extra charges and 18per GST every emi .don&#39;t buy anything online with emi .its the dark truth of emi .',
#  'What about no cost emi',
#  'Mathematical mistake in cost of Samsung watch. It is supposed to be 11,249. Was it purposely done!!!',
#  'Nothing is good when it comes at 28000 8gb ram 256gb storage',
#  'iPhone 14 on Amazon',
#  'Hey guys being a nothing phone user you could trust this phone <br>It has a really camera quality',
#  'Ameero wale deals hai sab😂',
#  'What about tablets?',
#  'Any video for over the ear headphones',
#  'Is pixel 6 still worth in 2023',
#  'Sony Linkbuds S for 9740 with icici credit card.',
#  'Beebom my request is to make video on tablet sale pls',
#  'First comment ❤',
#  'How&#39;s the vivobook pro 16??',
#  'Sennheiser cx plus SE',
#  'iPad 9th gen for 24k is great deal. Also on s6 lite.<br>:)',
#  'where did you see ipad for 24 k ?',
#  'First ❤',
#  'Gigabyte g5 gd, with discounts its the cheapest rtx 3050 laptop available',
#  'Please make a video on best anc headphones',
#  'Macbook air at 79900? I am seeing 82900',
#  'how about tabs/ipad',
#  'India top one',
#  'Can anybody tell me what would be the best time to get an iPhone 12?',
#  'Wait for some dayz',
#  'Till next model launch',
#  'Motorola Egde 30 Ultra Launch at <br>59,999 Offer Price 44,999 (128) 58,999 (256)',
#  'Best mobile for 20k super confused ???',
#  'i have to change my name after watching this video-  <br>gareeba',
#  'Philips Wireless On Ear Headphones TAH8506BK,<br>8000 rupees only',
#  'thumbnail op....lol',
#  'Moto 30 ultra is at 45k usally 55k',
#  'S20 FE is still good?',
#  'Samsung buds 2 at 6k',
#  'Could someone please suggest me a laptop? Budget is around 60k.',
#  '@xANIMESHx this one&#39;s at 79,990/- right now.',
#  'acer nitro 5 ryzen 5 5600h',
#  'GUYS!! <br>Realme GT 2 PRO is available at 43K (12gb + 256gb) and 39k for 8gb varient.<br>This phone is way better than s21fe or s20 FE 5G.<br>THIS ONE HAS 2K Screen!!!',
#  'Don&#39;t know how you can still suggest s20 fe on 2023 bruh',
#  'I am going to subscribe.',
#  'Realme gt 2 under 25k',
#  'the sound used for price tags is soo annoying',
#  'Realme GT 2 with SD 888',
#  'Asus zenbook duo 14 Pro ka review kre ki wo kya high gaming, high music task which is only done in, M1 Chip kya wo bhi yaha work krega aur high kaam hoskta hai ya nhi please bataye',
#  'Realme GT2 23999/- with bank offer',
#  'With exchange buying Samsung s21fe in 24k. Phone coming tomorrow 👀',
#  '@Shokuan Nobi ok ok..makess sense',
#  '@Ay Zu i already transferred into my laptop and most of my data is cloud so no worries about photos and videos and contact. For application i have all apk backup',
#  '@Shokuan Nobi when will you transfer your data?',
#  '@Ay Zu he&#39;ll come tomorrow and check everything and give new phone',
#  '@Ay Zu i ordered today',
#  'So you get a new phone and have to return old one at same time or how is it? Because you have to copy files and docs also right?',
#  'Galaxy buds 2pro',
#  'Why irritating bug clicking sound in the background 😒',
#  'You missed the legion series in laptop deals',
#  'You missed Samsung buds pro 2 it  available at 12k',
#  '@Rohit Ade emi mai charges lette hai na extra',
#  'got it for 9k with cc emi discount',
#  'no comments on headphones 😭😭😭',
#  'Boult Rover smartwatch @Rs.1999/-',
#  'No dont go noise check',
#  'Redmi K 50i at 20999 on Amazon',
#  'Galaxy book 3 at 56K.',
#  'Sony XM5 at 24.5k',
#  'Galaxy buds pro 2 at 8k',
#  'How?',
#  'Which card gets 2k off in iphone',
#  'Bhai kisi k pass icici ka credit card h to help kardo bhai😢',
#  'Has anyone noticed the number sound makes your teeth tick?',
#  'Task:   13',
#  'Xiaomi 12 Pro at 42,999',
#  'No offer of samsung galaxy watch 4 lte 👎',
#  'i want 1 phone under 30k... just tell me 1 the best one...',
#  'that tik tik sound irritates with earphones🥴🥴',
#  'I donno who is editing the video and doing the math, but Samsung watch ₹12999 with ₹1750 additional offer does not go as low as ₹10250. You need to buy a best budget calculator under ₹1000',
#  'I want to reset my phone so how to backup  telegram data ???',
#  'Samsung Tab s7 fe @ 35k',
#  'motorola edge 30 ultra',
#  '22K ko just nahi bolte bhai 💀',
#  'Deals to steal by Beebom',
#  'What about nothing ear 2 @ ₹8099',
#  'Petition to bring back the old intro',
#  'Please don&#39;t consider the s20 fe coz even tho the price is good its a 2+ yr old phone and not worth it in 2023',
#  'Nothing ear 2 deal?',
#  'Samsung buds 2 pro for 10000 Rupees',
#  'Ameero wali deals😢',
#  'Missed out on TV&#39;s',
#  'u forgot oppo enco buds 2',
#  'Pixel 6a',
#  'Bruhh what about realme gt 2 ?',
#  'that&#39;s a heater bro, it will help you in winters LOL',
#  'Iqoo Neo 6??',
#  'Realme gt2',
#  'Google pixel 6 pro',
#  's20fe is not good it doesn&#39;t have any update remaining',
#  'Bro anyone reading comments. Don&#39;t go for Samsung S20 FE. Its too old now....aur kitna nichodo ge.',
#  'Realme gt 2',
#  'Sir  redmi k50i',
#  'No deals on ipad',
#  'Guys buy S22 with exchange, dont buy 3-4 year old phones',
#  'Hum first 😂',
#  'Apple still expensive',
#  '😂',
#  'You missed out on Samsung Galaxy Watch 5 Pro',
#  'Just 21999 😂 just',
#  'You missed pixel 6A',
#  'Nokia laptop',
#  'Has anyone noticed that annoying sound in the background, it sounds like some wood-eating bug or some scratching, starting from <a href="https://www.youtube.com/watch?v=3MZ6aTpFrE0&amp;t=0m15s">0:15</a>',
#  '@Bullet Punch same I also thought my laptop speaker got busted :D',
#  'They put that effect for every number that appears, thought my headphones had a problem.',
#  '15k se niche wale bhi youtube dekhte hai bhai',
#  'samsung 5',
#  '📍Night camera bekar hai s21 fe<br>*Human subjet zoom krne k bd accga clearity nhi rhta__day aur night me<br>*Agr Moving human subject_to shaky pic aata<br>*Heat<br>*Battery drain fast normal usage<br>*long term chlega hi nhi _battery se preshn hoke_dusra mobile lena prega<br>*samsung lag hota_ long term me_ history dekh lo<br>*water proff ka quality dekh lo gupta ji information channel per<br>*wireless charger _normal user ko koi frk nhi prta ye rhe ya nhi rhe<br>*one plus 11 r thk rhega ya vivo v27 sb _jisme sony ka sensor lga ho camera m<br>*yhi sb youtubers ka video dekh ke liya tha_s21fe _aaj pchta raha hu__in logo per vishwash nhi karna<br>*Honest review leker bs pachtaoge<br>_hm time nikar kr ye comment likh rhe_jisse tumhara paisa save ho',
#  'bro your video is for only rich people i request you to please do videos for poor people for us',
#  'I phone 11 is also a poor deal',
#  'Dude this channel is solely for rich guys😂😂😂.  High commission for high priced items referral 😂😂',
#  'Paisa nahin Hain Bhai .kuch jugaad kar na . 😵\u200d💫',
#  'Don&#39;t buy the Samsung S20 FE 5G in 2023, I&#39;ve it from 2021. Simply will say, not worth it currently.',
#  'Other than apple or high end, all remaining Smart watches are always bad deals as these are just fake in terms of Sensors and just a step counter.',
#  'Do you seriously say S20Fe - A 3 to 4 year old phone is good phone to buy even in 2023?? Like with all due respect, i completely don&#39;t agree . Please don&#39;t promote 3-4 year old phone. I know the phone is great, but at it&#39;s age only. Not in 2023',
#  '<a href="https://www.youtube.com/watch?v=3MZ6aTpFrE0&amp;t=1m33s">1:33</a> the text typing sound is annoying',
#  'One plus deal is really good.',
#  'Pixel 7 is available at 49k for a long time. Are you guys living under rock or wut!',
#  'Bhai phali video hai kya pagala gye ho kya s20fe bhai bs karo yarr',
#  'U still cheering for s20 fe at this time. That&#39;s sad.',
#  'You missed iphone 14',
#  'S20 FE is too old, not recommended',
#  'ahhaha pls dont buy Ideapad gaming, when legion 5 exist, i got the legion 5 and its pretty good, better than the ideapad, also back in 2022 around august or something, legion 5 was available from like under 59k',
#  'i think before buying online one should always look for offline store ......i got S23 Ultra for 1.01 lakh .....512 gb ......after GST rebate ......invoice value was 1.15 lakh ......',
#  'That infographic SFX is irritating &amp; irrelevant 😒',
#  'galaxy watch 5 pro. available for 31k.. 9k straight discount.',
#  'Can I ask what happened with your eyes?? 👀',
#  'Is it just me or did anyone else also get annoyed by his usage and extra weight/emphasis on the word “Tthhousand”',
#  'Stop recommending S20 FE in 2023. It is a 2 year old devices and the update cycle is almost near the end. S21 FE is better.',
#  'Nothing for a common man. 🙄',
#  'Guys don&#39;t buy realme gt neo 3t........ It&#39;s full of bugs ...... Waste of money',
#  'someone stop this guy..omg this guy is a joke lol 😂',
#  'Is it just me or did anyone else also get annoyed by his usage and extra weight/emphasis on the word “Tthhousand”',
#  'The tirrr tirrr sound is really irritating',
#  'Dude what&#39;s that kkrrrrrrr sound.. that&#39;s annoying',
#  'All this are overhyped product',
#  'To al those who are saying dont buy s20 fe cuz it won&#39;t get updates anymore. Guys the phone is superb! No problem if it won&#39;t get updates anymore. Software updates ain&#39;t the most important thing if we get a great experience.<br><br>Chinese phones with shit cameras &amp; shit ui which lags on day to day tasks, and recieves updates very late, which results in motherboard dead 🤧<br><br>S20 fe is a much better deal.',
#  '+ i see someone commenting Exynos 990. <br><br>There is Snapdragon 865',
#  'creaky Sound. make this video Annoying',
#  'Amazon is overrated',
#  'crosses eyes lodu']

# %% [markdown]
# # Filtering and cleaning

# %%
def filterDF(df):
    df = df.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))
    df['Comments'] = df['Comments'].apply(lambda x: re.split('<a href="https:\/\/.*', str(x))[0])
    def process_content(content):
        return " ".join(re.findall("[A-Za-z]+",content))

    df['Comments'] = df['Comments'].apply(process_content).str.lower()
    df['Comments'].replace('', np.nan, inplace=True)
    df.dropna(inplace=True)
    return df

# %%
HighLvldf_filtered = filterDF(HighLvldf)

# %%
HighLvldf_filtered
# Out:
#                                               Comments Comment ID
# 0    hey guys any other awesome deal that we missed...   197154_1
# 1    which extension was it you used to track the p...   274067_1
# 2          realme gt neo t will be back in sale or not   857536_1
# 3    got few deals for myself myself sony wh xm rs ...   724364_1
# 4    sir could you please suggest any way to update...   353754_1
# ..                                                 ...        ...
# 497                                       much awaited   198273_1
# 498                           deals to steal by beebom   249659_1
# 499                                   good evening bee   465840_1
# 500                                          hum first   743612_1
# 503                                              first   987781_1
#
# [502 rows x 2 columns]

# %%
AllLvldf_filtered = filterDF(AllLvldf)

# %%
AllLvldf_filtered
# Out:
#                                               Comments Comment ID
# 0    hey guys any other awesome deal that we missed...   298107_1
# 1    what s best smartphone under k inr for best ca...   774454_1
# 2    whats best smartphone for best camera under k ...   378283_1
# 3    please make best smartphone under k no one tou...   674053_1
# 4            there is no discount on asus vivobook pro   390621_1
# ..                                                 ...        ...
# 949  to al those who are saying dont buy s fe cuz i...   680052_1
# 950  i see someone commenting exynos br br there is...   969564_1
# 951              creaky sound make this video annoying   194318_1
# 952                                amazon is overrated   515685_1
# 953                                  crosses eyes lodu    85359_1
#
# [946 rows x 2 columns]

# %%
AllLvldf_filtered.to_csv("3MZ6aTpFrE0_Afiltered.csv")

# %%
HighLvldf_filtered.to_csv("3MZ6aTpFrE0_Hfiltered.csv")
